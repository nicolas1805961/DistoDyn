# %%
import pickle

with open("mut_types_dict.pkl", "rb") as f:
    data = pickle.load(f)
    print(data['protein_0'])
    print(len(data['protein_0']))
# Out:
# ['D1Q', 'D1E', 'D1N', 'D1H', 'D1R', 'D1K', 'D1T', 'D1S', 'D1A', 'D1G', 'D1M', 'D1L', 'D1V', 'D1I', 'D1W', 'D1Y', 'D1F', 'D1P', 'D1C', 'insG1', 'insA1', 'delD1', 'E2Q', 'E2N', 'E2H', 'E2D', 'E2R', 'E2K', 'E2T', 'E2S', 'E2A', 'E2G', 'E2M', 'E2L', 'E2V', 'E2I', 'E2W', 'E2Y', 'E2F', 'E2P', 'E2C', 'insG2', 'insA2', 'delE2', 'V3Q', 'V3E', 'V3N', 'V3H', 'V3D', 'V3R', 'V3K', 'V3T', 'V3S', 'V3A', 'V3G', 'V3M', 'V3L', 'V3I', 'V3W', 'V3Y', 'V3F', 'V3P', 'V3C', 'insG3', 'insA3', 'delV3', 'T4Q', 'T4E', 'T4N', 'T4H', 'T4D', 'T4R', 'T4K', 'T4S', 'T4A', 'T4G', 'T4M', 'T4L', 'T4V', 'T4I', 'T4W', 'T4Y', 'T4F', 'T4P', 'T4C', 'insG4', 'insA4', 'delT4', 'I5Q', 'I5E', 'I5N', 'I5H', 'I5D', 'I5R', 'I5K', 'I5T', 'I5S', 'I5A', 'I5G', 'I5M', 'I5L', 'I5V', 'I5W', 'I5Y', 'I5F', 'I5P', 'I5C', 'insG5', 'insA5', 'delI5', 'H6Q', 'H6E', 'H6N', 'H6D', 'H6R', 'H6K', 'H6T', 'H6S', 'H6A', 'H6G', 'H6M', 'H6L', 'H6V', 'H6I', 'H6W', 'H6Y', 'H6F', 'H6P', 'H6C', 'insG6', 'insA6', 'delH6', 'L7Q', 'L7E', 'L7N', 'L7H', 'L7D', 'L
# ...

# %%
import pickle

with open("mega_splits.pkl", "rb") as f:
    data = pickle.load(f)
    print(data.keys())
    print(data['train'])
# Out:
# dict_keys(['train', 'val', 'test', 'train_s669', 'cv_train_0', 'cv_val_0', 'cv_test_0', 'cv_train_1', 'cv_val_1', 'cv_test_1', 'cv_train_2', 'cv_val_2', 'cv_test_2', 'cv_train_3', 'cv_val_3', 'cv_test_3', 'cv_train_4', 'cv_val_4', 'cv_test_4'])
# ...
